# %%
import json
class EdyodaRestaurant:

    def __init__(self):
        self.restro_name = EdyodaRestaurant
        self.food = {}
        self.food_ID = len(self.food) + 1
        self.user_details = {}
        self.ordered_item = []

    def check_admin(self):
        name = input("Enter Admin name : ")
        password = input("Enter Admin Password : ")

        if name == name and password == password:
            print("..........Admin login successFully........")
        else:
            print(".........Incorrect Admin Details.........")

    def add_food_item(self):
        try:
            name = input("Enter the food name : ")
            quantity = eval(input("Enter the quantity in values only : "))
            price = eval(input("Enter the price in Rs only : "))
            stock = eval(input("Enter the available stock in values only : "))
            discount = eval(input("Enter the discount in Rs only : "))
            food_item = {"Name": name, "Quantity": quantity, "Price": price, "Stock": stock, "Discount": discount}
            self.food_ID = len(self.food) + 1
            self.food[self.food_ID] = food_item
            print("\n!! Food Item added successfully !!\n")
            print("Newly Added items :", self.food, "\n")
        except Exception as e:
            print("\n!! Something went wrong please try again !!\n")

    def edit_food_item(self):
        try:
            x = int(input("Enter the Food ID you want to update : \n"))
            if x in self.food.keys():
                print(
                    "1. Update Food Name\n2. Update Quantity\n3. Update Price\n4. Update Stock\n5. Update Discount \n")
                y = input("Enter the number only : ")
                if y == "1":
                    self.food[x]["Name"] = input("Updated Food name : ")
                    print("\n!! Successfully Updated !!\n")
                elif y == "2":
                    self.food[x]["Quantity"] = float(input("Updated Quantity in values only : "))
                    print("\n!! Successfully Updated !!\n")
                elif y == "3":
                    self.food[x]["Price"] = float(input("Updated Price in Rs only : "))
                    print("\n!! Successfully Updated !!\n")
                elif y == "4":
                    self.food[x]["Stock"] = float(input("Updated Stock in values only : "))
                    print("\n!! successfully Updated !!\n")
                elif y == "5":
                    self.food[x]["Discount"] = float(input("Updated Discount in Rs only : "))
                    print("\n!! Successfully Updated !!\n")
                else:
                    print("!! Sorry Invalid Number !!\n")
            else:
                print("\n!! Incorrect Food ID !!\n")
        except Exception as e:
            print("\n!! Something went wrong please try again !!\n")

    def view_food_item(self):
        print("List of Food Items : \n")
        if len(self.food) != 0:
            for i in self.food:
                print(f"Food Id : {i}")
                for j in self.food[i]:
                    print(j, ":", self.food[i][j])
                print()
        else:
            print("!! Sorry No Food Items is Added !!\n")

    def remove_food_item(self):
        try:
            print("!! Warning !!\nFood Item will Delete Permanently\n")
            print("Enter the Food ID ")
            x = int(input())
            if x in self.food.keys():
                del self.food[x]
                print("\n!! Food item deleted successfully !!\n")
                print("Updated Food List\n", self.food)
            else:
                print("!! Incorrect Food ID\n !!")
        except Exception as e:
            print("\n!! Something went wrong please try again !!\n")

    def user_register(self):
        try:
            while True:
                user_name = input("Enter your full name : ")
                phone_no = int(input("Enter your 10 digit phone number : "))
                email = input("Enter your email id : ")
                password = input("Enter your password : ")
                address = input("Enter your address with area PIN code : ")
                self.user_details = {"User Name": user_name, "Phone No.": phone_no, "Email_ID": email,
                                     "Password": password, "Address": address}
                print("\n!! Your Account is Created Successfully !!\n")
                print(f"Welcome TO {self.restro_name} Restaurant\n")
                print("User Details : ")
                for i in self.user_details:
                    print(i, ":", self.user_details[i])
                break

        except Exception as e:
            print("\n!! Something went wrong please try again !!\n ")

    def user_login(self):
        try:
            while True:
                print(f"Welcome TO {self.restro_name} Restaurant\n\n")
                email = input("Enter Your Email ID : ")
                pas = input("Enter Your Password : ")
                if len(self.user_details) != 0:
                    if email == self.user_details["Email_ID"] and pas == self.user_details["Password"]:
                        print("\n!! Login successfully !!")
                        while True:
                            print("\nEnter the Below Options\n")
                            print("1. Place New Order\n2. Check Order History\n3. Update Your Profile Details\n4. Exit")
                            z = input()
                            if z == "1":
                                self.place_order()
                            elif z == "2":
                                self.ordered_history()
                            elif z == "3":
                                self.update_details()
                            elif z == "4":
                                break
                            else:
                                print("invalid Number")
                    else:
                        print("\n!! Incorrect Email or Password!!\n")
                else:
                    print("\n! There is no Account with this Email ID !\n\n!! Please Create Your Account First!!\n")
                    break
                break
        except Exception as e:
            print("\n!! Something went wrong please try again !!")
    
    def place_order(self):
        try:
            if len(self.food) != 0:
                menu = []
                for items in self.food:
                    menu.append([self.food[items]["Name"], self.food[items]["Quantity"], self.food[items]["Price"]])
                for i in menu:
                    print(i)
                while True:
                    print("\nEnter 1 to Place the Order\nEnter 2 to Exit ")
                    x = input()
                    if x == "1":
                        print("Enter the Food ID to Order your Food : ")
                        y = input().split(",")
                        for i in y:
                            z = int(i)
                            if z <= len(menu):
                                self.ordered_item.append(menu[z - 1])
                            else:
                                print("We Don't have this Food Item : ", z)
                        print("List of food item you selected : \n")
                        for j in self.ordered_item:
                            print(j)
                    elif x == "2":
                        break
                    else:
                        print("!! Invalid Number !!\n")
            else:
                print("\n!! Sorry! No Food Items are available Now !!\n")

        except Exception as e:
            print("\n!! Something went wrong try again !!")

    
    def ordered_history(self):
        print("\nList of Previous ordered : ")
        for i in self.ordered_item:
            print(i)

    def update_details(self):
        try:
            while True:
                print("Select Below Options to Update Your Profile Details\n")
                print("1. Name\n2. Phone number\n3. Email ID\n4. Password\n5. Address\n6. Exit\n")
                x = input()
                if x == "1":
                    self.user_details["User Name"] = input("Enter your updated full name : ")
                    print("\n!! Detail Updated Successfully !!\n")
                elif x == "2":
                    self.user_details["Phone No."] = int(input("Enter your updated 10 digit phone number : "))
                    print("\n!! Detail Updated Successfully !!\n")
                elif x == "3":
                    self.user_details["Email_ID"] = input("Enter your updated email id : ")
                    print("\n!! Detail Updated Successfully !!")

                elif x == "4":
                    self.user_details["Password"] = input("Enter your updated password : ")
                    print("\n!! Detail Updated Successfully !!\n")

                elif x == "5":
                    self.user_details["Address"] = input("Enter your updated address with area PIN code ")
                    print("\n!! Detail Updated Successfully !!\n")

                elif x == "6":
                    break
                else:
                    print("\n!! Invalid Number Entered !!\n")

                if x in ["1", "2", "3", '4', "5"]:
                    for i in self.user_details:
                        print(i, ":", self.user_details[i])
                else:
                    print("\nPlease Enter correct Input\n")
        except Exception as e:
            print("\n!! Something went wrong please try again !!\n ") 
            
F = EdyodaRestaurant()
print(F.check_admin())
print(F.add_food_item())
print(F.add_food_item())
print(F.add_food_item())
print(F.edit_food_item())
print(F.view_food_item())
print(F.remove_food_item())
print(F.user_register())
print(F.user_login())
print(F.place_order())
print(F.ordered_history())
print(F.update_details())
# Out:
# Enter Admin name : Sathya
# Enter Admin Password : Vengadaa
# ..........Admin login successFully........
# None
# Enter the food name : Paneer
# Enter the quantity in values only : 1
# Enter the price in Rs only : 250
# Enter the available stock in values only : 20
# Enter the discount in Rs only : 10
#
# !! Food Item added successfully !!
#
# Newly Added items : {1: {'Name': 'Paneer', 'Quantity': 1, 'Price': 250, 'Stock': 20, 'Discount': 10}}
#
# None
# Enter the food name : Dosai
# Enter the quantity in values only : 2
# Enter the price in Rs only : 45
# Enter the available stock in values only : 15
# Enter the discount in Rs only : 3
#
# !! Food Item added successfully !!
#
# Newly Added items : {1: {'Name': 'Paneer', 'Quantity': 1, 'Price': 250, 'Stock': 20, 'Discount': 10}, 2: {'Name': 'Dosai', 'Quantity': 2, 'Price': 45, 'Stock': 15, 'Discount': 3}}
#
# None
# Enter the food name : Burger
# Enter the quantity in values only : 1
# Enter the price in Rs only : 350
# Enter the available stock in values only : 5
# Enter the discount in Rs only : 100
#
# !! Food Item added successfully !!
#
# Newly Added items : {1: {'Name': 'Paneer', 'Quantity': 1, 'Price': 250, 'Stock': 20, 'Discount': 10}, 2: {'Name': 'Dosai', 'Quantity': 2, 'Price': 45, 'Stock': 15, 'Discount': 3}, 3: {'Name': 'Burger', 'Quantity': 1, 'Price': 350, 'Stock': 5, 'Discount': 100}}
#
# None
# Enter the Food ID you want to update :
# 2
# 1. Update Food Name
# 2. Update Quantity
# 3. Update Price
# 4. Update Stock
# 5. Update Discount
#
# Enter the number only : 1
# Updated Food name : Pizza
#
# !! Successfully Updated !!
#
# None
# List of Food Items :
#
# Food Id : 1
# Name : Paneer
# Quantity : 1
# Price : 250
# Stock : 20
# Discount : 10
#
# Food Id : 2
# Name : Pizza
# Quantity : 2
# Price : 45
# Stock : 15
# Discount : 3
#
# Food Id : 3
# Name : Burger
# Quantity : 1
# Price : 350
# Stock : 5
# Discount : 100
#
# None
# !! Warning !!
# Food Item will Delete Permanently
#
# Enter the Food ID
# 2
#
# !! Food item deleted successfully !!
#
# Updated Food List
#  {1: {'Name': 'Paneer', 'Quantity': 1, 'Price': 250, 'Stock': 20, 'Discount': 10}, 3: {'Name': 'Burger', 'Quantity': 1, 'Price': 350, 'Stock': 5, 'Discount': 100}}
# None
# Enter your full name : Sathya
# Enter your 10 digit phone number : 9876543210
# Enter your email id : sath@gmail.com
# Enter your password : 123456
# Enter your address with area PIN code : 610002
#
# !! Your Account is Created Successfully !!
#
# Welcome TO <class '__main__.EdyodaRestaurant'> Restaurant
#
# User Details :
# User Name : Sathya
# Phone No. : 9876543210
# Email_ID : sath@gmail.com
# Password : 123456
# Address : 610002
# None
# Welcome TO <class '__main__.EdyodaRestaurant'> Restaurant
#
#
# Enter Your Email ID : sath@gmail.com
# Enter Your Password : 123456
#
# !! Login successfully !!
#
# Enter the Below Options
#
# 1. Place New Order
# 2. Check Order History
# 3. Update Your Profile Details
# 4. Exit
# 1
# ['Paneer', 1, 250]
# ['Burger', 1, 350]
#
# Enter 1 to Place the Order
# Enter 2 to Exit
# 1
# Enter the Food ID to Order your Food :
# 3
# We Don't have this Food Item :  3
# List of food item you selected :
#
#
# Enter 1 to Place the Order
# Enter 2 to Exit
# 1
# Enter the Food ID to Order your Food :
# 2
# List of food item you selected :
#
# ['Burger', 1, 350]
#
# Enter 1 to Place the Order
# Enter 2 to Exit
# 2
#
# Enter the Below Options
#
# 1. Place New Order
# 2. Check Order History
# 3. Update Your Profile Details
# 4. Exit
# 2
#
# List of Previous ordered :
# ['Burger', 1, 350]
#
# Enter the Below Options
#
# 1. Place New Order
# 2. Check Order History
# 3. Update Your Profile Details
# 4. Exit
# 2
#
# List of Previous ordered :
# ['Burger', 1, 350]
#
# Enter the Below Options
#
# 1. Place New Order
# 2. Check Order History
# 3. Update Your Profile Details
# 4. Exit
# 3
# Select Below Options to Update Your Profile Details
#
# 1. Name
# 2. Phone number
# 3. Email ID
# 4. Password
# 5. Address
# 6. Exit
#
# 4
# Enter your updated password : 010203
#
# !! Detail Updated Successfully !!
#
# User Name : Sathya
# Phone No. : 9876543210
# Email_ID : sath@gmail.com
# Password : 010203
# Address : 610002
# Select Below Options to Update Your Profile Details
#
# 1. Name
# 2. Phone number
# 3. Email ID
# 4. Password
# 5. Address
# 6. Exit
#
# 6
#
# Enter the Below Options
#
# 1. Place New Order
# 2. Check Order History
# 3. Update Your Profile Details
# 4. Exit
# 4
# None
# ['Paneer', 1, 250]
# ['Burger', 1, 350]
#
# Enter 1 to Place the Order
# Enter 2 to Exit
# 2
# None
#
# List of Previous ordered :
# ['Burger', 1, 350]
# None
# Select Below Options to Update Your Profile Details
#
# 1. Name
# 2. Phone number
# 3. Email ID
# 4. Password
# 5. Address
# 6. Exit
#
# 6
# None
